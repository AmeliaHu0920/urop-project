# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data_big.csv')
data
# Out:
#      Unnamed: 0 material_id                  elements formula_pretty_reduced  \
# 0             0    mp-10103   ['Li', 'F', 'Al', 'Yb']               LiYbAlF6
# 1             1    mp-10182         ['Li', 'P', 'Zn']                  LiZnP
# 2             2    mp-10250         ['Li', 'F', 'Ba']                 BaLiF3
# 3             3    mp-10251         ['Li', 'O', 'Dy']                 LiDyO2
# 4             4    mp-10485        ['Li', 'Sb', 'Ba']                 BaLiSb
# ..          ...         ...                       ...                    ...
# 868         868   mp-989579  ['Rb', 'Li', 'Tl', 'Cl']             Rb2LiTlCl6
# 869         869   mp-989583  ['Rb', 'Li', 'In', 'Cl']             Rb2LiInCl6
# 870         870     mp-9912         ['Li', 'P', 'Ce']                Li2CeP2
# 871         871     mp-9915         ['Li', 'Be', 'P']                  LiBeP
# 872         872     mp-9919        ['Li', 'Zn', 'Sb']                 LiZnSb
#
# ...

# %%
#optional: convert columns into lists
fav = data['fav'].tolist()
fav_RT = data['298'].tolist()
first_f_i = data['first_f_i'].tolist()
first_f_a = data['first_f_a'].tolist()
width = data['relative_w'].tolist()

# %%
sns.scatterplot(data=data, x='fav',y='298')
# Out:
# <AxesSubplot:xlabel='fav', ylabel='298'>

# %%
sns.scatterplot(data=data, x='fav',y='first_f_i')
# Out:
# <AxesSubplot:xlabel='fav', ylabel='first_f_i'>

# %%
sns.scatterplot(data=data, x='fav',y='first_f_a')
# Out:
# <AxesSubplot:xlabel='fav', ylabel='first_f_a'>

# %%
sns.scatterplot(data=data, x='fav',y='relative_w')
# Out:
# <AxesSubplot:xlabel='fav', ylabel='relative_w'>

# %%
sns.scatterplot(data=data, x='298',y='first_f_i')
# Out:
# <AxesSubplot:xlabel='298', ylabel='first_f_i'>

# %%
sns.scatterplot(data=data, x='298',y='first_f_a')
# Out:
# <AxesSubplot:xlabel='298', ylabel='first_f_a'>

# %%
sns.scatterplot(data=data, x='298',y='relative_w')
# Out:
# <AxesSubplot:xlabel='298', ylabel='relative_w'>

# %%
sns.scatterplot(data=data, x='first_f_i',y='first_f_a')
# Out:
# <AxesSubplot:xlabel='first_f_i', ylabel='first_f_a'>

# %%
sns.scatterplot(data=data, x='first_f_i',y='relative_w')
# Out:
# <AxesSubplot:xlabel='first_f_i', ylabel='relative_w'>

# %%
sns.scatterplot(data=data, x='first_f_a',y='relative_w')
# Out:
# <AxesSubplot:xlabel='first_f_a', ylabel='relative_w'>
